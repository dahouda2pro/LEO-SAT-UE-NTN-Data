# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import dendrogram

import plotly.express as px

import keras
from keras.layers import Dense,Dropout

import pandas as pd
from tensorflow.keras.models import Sequential

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
plt.rcParams['figure.figsize'] = (20, 10)

#define a custom palette
customPalette = ['#630C3A','#39C8C6','#D3500C','#FFB139']
sns.set_palette(customPalette)
sns.palplot(customPalette)

# %%
# Loading UE Data
UE_data = pd.read_csv('NTN_Dataset.csv')
UE_data.head()
# Out:
#    Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0      0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1      0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2      0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3      0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4      0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
#
#         Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0  304.330261       165.600340  165.600340       -135.600340
# 1  325.251116       165.257559  165.257559       -135.257559
# 2  313.516082       165.600340  165.600340       -135.600340
# 3  326.362599       165.949179  165.949179       -135.949179
# 4  325.250193       165.257957  165.257957       -135.257957
#
#    Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                  -135.600340    -90.917295   20  52.998799  37.947299
# 1                  -135.257559    -90.574514   20  53.341580  38.290080
# 2                  -135.600340    -90.917295   20  52.998799  37.947299
# 3                  -135.949179    -91.266134   20  52.649960  37.598460
# 4                  -135.257957    -90.574912   20  53.341182  38.289683
#
#        Eb/No  Propagation Delay  Propagation Distance  Spectral Flux Density
# 0  40.957599           0.001046            313.516082            -165.968795
# 1  41.300380           0.001005            301.384403            -165.626014
# 2  40.957599           0.001046            313.516082            -165.968795
# 3  40.608760           0.001089            326.363646            -166.317634
# 4  41.299982           0.001005            301.398207            -165.626412

# %%
# Select some feature
x = UE_data.iloc[0:4999, 1:4]
x
# Out:
#       CellType  Latitude  Longitude
# 0            0    0.2928  -115.8555
# 1            0    0.2928  -115.8555
# 2            1    0.2928  -115.8555
# 3            1    0.2928  -115.8555
# 4            2    0.2928  -115.8555
# ...        ...       ...        ...
# 4994         1    0.5686  -116.1636
# 4995         1    0.5686  -116.1636
# 4996         2    0.5686  -116.1636
# 4997         2    0.5686  -116.1636
# 4998         0   -0.1092  -115.3795
#
# [4999 rows x 3 columns]

# %%
# Clustering
kmeans = KMeans(3)

# %% [markdown]
# # Clustering results

# %%
# Clustering resuts
identified_clusaters = kmeans.fit_predict(x)
identified_clusaters
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
data_with_clusters = x.copy()
data_with_clusters['Cluster'] = identified_clusaters
data_with_clusters
# Out:
#       CellType  Latitude  Longitude  Cluster
# 0            0    0.2928  -115.8555        2
# 1            0    0.2928  -115.8555        2
# 2            1    0.2928  -115.8555        2
# 3            1    0.2928  -115.8555        2
# 4            2    0.2928  -115.8555        2
# ...        ...       ...        ...      ...
# 4994         1    0.5686  -116.1636        2
# 4995         1    0.5686  -116.1636        2
# 4996         2    0.5686  -116.1636        2
# 4997         2    0.5686  -116.1636        2
# 4998         0   -0.1092  -115.3795        2
#
# [4999 rows x 4 columns]

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(data_with_clusters['Longitude'],data_with_clusters['Latitude'], c=data_with_clusters['Cluster'], cmap='rainbow')
legend1 = ax.legend(*scatter.legend_elements(), loc='lower left', title='Clusters')
ax.add_artist(legend1)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.xlim(-120, -112)
plt.ylim(-2,3)
plt.show()

# %%
data_with_clusters['Latitude'].min()
# Out:
# -1.5239

# %%
data_with_clusters['Latitude'].max()
# Out:
# 2.2959

# %%
data_with_clusters['Latitude'].mean()
# Out:
# 0.44020052010402083

# %%
data_with_clusters['Longitude'].min()
# Out:
# -118.6789

# %%
data_with_clusters['Longitude'].max()
# Out:
# -113.5212

# %%
data_with_clusters['Longitude'].mean()
# Out:
# -116.13100918183636

# %%
data_with_clusters['Longitude'].median()
# Out:
# -116.164
