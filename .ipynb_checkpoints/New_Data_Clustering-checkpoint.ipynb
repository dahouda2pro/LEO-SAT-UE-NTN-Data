# %% [markdown]
# # 1. Importing Libraries

# %%
import numpy as np
from numpy import cos, sin, arcsin, sqrt
import pandas as pd
import math
from math import radians
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import dendrogram

import plotly.express as px

import keras
from keras.layers import Dense,Dropout

import pandas as pd
from tensorflow.keras.models import Sequential
from sklearn import metrics


import joblib
import time
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
plt.rcParams['figure.figsize'] = (20, 10)

#define a custom palette
customPalette = ['#630C3A','#39C8C6','#D3500C','#FFB139']
sns.set_palette(customPalette)
sns.palplot(customPalette)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 70D6-B03A
#
#  Directory of C:\Users\MWAMBA\Clustering_HO
#
# 02/13/2023  11:50 AM    <DIR>          .
# 02/13/2023  11:50 AM    <DIR>          ..
# 02/10/2023  07:57 PM    <DIR>          .ipynb_checkpoints
# 02/08/2023  06:41 PM           427,518 2021_FEBRUARY.csv
# 01/11/2023  04:45 PM        25,937,760 Candidate_Cell.csv
# 01/14/2023  10:47 PM         1,763,559 Clustering.ipynb
# 02/13/2023  11:48 AM           293,484 Figure_12.jpeg
# 02/13/2023  11:48 AM           277,282 Figure_3.jpeg
# 02/13/2023  11:48 AM           251,143 Figure_4.jpeg
# 02/13/2023  11:48 AM           293,484 Figure_5.jpeg
# 02/13/2023  11:48 AM            49,077 Figure_6.jpeg
# 02/07/2023  03:46 PM           310,516 Figure_6a.jpeg
# 02/13/2023  11:50 AM            31,677 Figure_Acc.jpeg
# 02/13/2023  11:50 AM            17,681 Figure_Loss.jpeg
# 02/13/2023  11:50 AM            10,186 Figure_LossAcc.png
# 01/18/2023  01:04 PM    <DIR>          Graphs
# 02/08/2023  03:35 PM            21,363 LEO1_LLA_Position.csv
# 01/04/2023  03:15 PM    <DIR>          New_Data
# 02/13/2023  11:50 AM         2,865,232 New_Data_Clustering.ipynb
# 12/13/2022  12:12 PM        11,102,849 NTN.csv
# 01/09/2023  10:47 AM        87,511,443 NTN_Dataset.csv
# 01/09/2023  10:47 AM        87,511,443 NTN_Dataset_2.csv
# 02/13/2023  11:48 AM            64,224 plot_MW_vs_LogP.jpeg
# 01/16/2023  04:10 PM            16,140 plot_MW_vs_LogP.pdf
# 01/11/2023  04:39 PM           233,606 Untitled.ipynb
#               20 File(s)    218,989,667 bytes
#                5 Dir(s)  50,951,778,304 bytes free

# %%
# Loading UE Data
Satellite_data = pd.read_csv('LEO1_LLA_Position.csv')
Satellite_data.head()
# Out:
#    Time  Lat (deg)  Lon (deg)    Alt (km)  speed (km/sec)
# 0     0      0.127   -116.637  300.000104            7.56
# 1     1      0.159   -116.583  300.000163            7.56
# 2     2      0.191   -116.529  300.000235            7.56
# 3     3      0.223   -116.475  300.000320            7.56
# 4     4      0.254   -116.421  300.000418            7.56

# %% [markdown]
# # 2. Loading The Data

# %%
pd.set_option('display.max_columns', None)
# Loading UE Data
UE_data = pd.read_csv('NTN_Dataset.csv')
UE_data.head()
# Out:
#    Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0      0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1      0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2      0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3      0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4      0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
#
#         Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0  304.330261       165.600340  165.600340       -135.600340
# 1  325.251116       165.257559  165.257559       -135.257559
# 2  313.516082       165.600340  165.600340       -135.600340
# 3  326.362599       165.949179  165.949179       -135.949179
# 4  325.250193       165.257957  165.257957       -135.257957
#
#    Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                  -135.600340    -90.917295   20  52.998799  37.947299
# 1                  -135.257559    -90.574514   20  53.341580  38.290080
# 2                  -135.600340    -90.917295   20  52.998799  37.947299
# 3                  -135.949179    -91.266134   20  52.649960  37.598460
# 4                  -135.257957    -90.574912   20  53.341182  38.289683
#
#        Eb/No  Propagation Delay  Propagation Distance  Spectral Flux Density
# 0  40.957599           0.001046            313.516082            -165.968795
# 1  41.300380           0.001005            301.384403            -165.626014
# 2  40.957599           0.001046            313.516082            -165.968795
# 3  40.608760           0.001089            326.363646            -166.317634
# 4  41.299982           0.001005            301.398207            -165.626412

# %%
UE_data.shape
# Out:
# (377454, 20)

# %%
#UE_data = UE_data.loc[UE_data['Time'] > 0]

# %%
 UE_data = UE_data.loc[UE_data['Index'].unique()]

# %%
UE_data
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2          0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3          0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4          0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# ...      ...       ...       ...        ...        ...         ...        ...
# 62904  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62905  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62906  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62907  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62908  10484         2   -1.1051  -118.0414   0.000000  151.459006 -72.619323
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 2      313.516082       165.600340  165.600340       -135.600340
# 3      326.362599       165.949179  165.949179       -135.949179
# 4      325.250193       165.257957  165.257957       -135.257957
# ...           ...              ...         ...               ...
# 62904    0.000000         0.000000    0.000000          0.000000
# 62905    0.000000         0.000000    0.000000          0.000000
# 62906    0.000000         0.000000    0.000000          0.000000
# 62907    0.000000         0.000000    0.000000          0.000000
# 62908  316.343953       166.979635  166.979635       -136.979635
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 2                      -135.600340    -90.917295   20  52.998799  37.947299
# 3                      -135.949179    -91.266134   20  52.649960  37.598460
# 4                      -135.257957    -90.574912   20  53.341182  38.289683
# ...                            ...           ...  ...        ...        ...
# 62904                     0.000000      0.000000    0   0.000000   0.000000
# 62905                     0.000000      0.000000    0   0.000000   0.000000
# 62906                     0.000000      0.000000    0   0.000000   0.000000
# 62907                     0.000000      0.000000    0   0.000000   0.000000
# 62908                  -136.979635    -92.296591   20  51.619504  36.568004
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
# 2      40.957599           0.001046            313.516082
# 3      40.608760           0.001089            326.363646
# 4      41.299982           0.001005            301.398207
# ...          ...                ...                   ...
# 62904   0.000000           0.000000              0.000000
# 62905   0.000000           0.000000              0.000000
# 62906   0.000000           0.000000              0.000000
# 62907   0.000000           0.000000              0.000000
# 62908  39.578304           0.001226            367.472295
#
#        Spectral Flux Density
# 0                -165.968795
# 1                -165.626014
# 2                -165.968795
# 3                -166.317634
# 4                -165.626412
# ...                      ...
# 62904               0.000000
# 62905               0.000000
# 62906               0.000000
# 62907               0.000000
# 62908            -167.348090
#
# [62909 rows x 20 columns]

# %%
UE_data
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2          0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3          0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4          0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# ...      ...       ...       ...        ...        ...         ...        ...
# 62904  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62905  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62906  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62907  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62908  10484         2   -1.1051  -118.0414   0.000000  151.459006 -72.619323
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 2      313.516082       165.600340  165.600340       -135.600340
# 3      326.362599       165.949179  165.949179       -135.949179
# 4      325.250193       165.257957  165.257957       -135.257957
# ...           ...              ...         ...               ...
# 62904    0.000000         0.000000    0.000000          0.000000
# 62905    0.000000         0.000000    0.000000          0.000000
# 62906    0.000000         0.000000    0.000000          0.000000
# 62907    0.000000         0.000000    0.000000          0.000000
# 62908  316.343953       166.979635  166.979635       -136.979635
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 2                      -135.600340    -90.917295   20  52.998799  37.947299
# 3                      -135.949179    -91.266134   20  52.649960  37.598460
# 4                      -135.257957    -90.574912   20  53.341182  38.289683
# ...                            ...           ...  ...        ...        ...
# 62904                     0.000000      0.000000    0   0.000000   0.000000
# 62905                     0.000000      0.000000    0   0.000000   0.000000
# 62906                     0.000000      0.000000    0   0.000000   0.000000
# 62907                     0.000000      0.000000    0   0.000000   0.000000
# 62908                  -136.979635    -92.296591   20  51.619504  36.568004
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
# 2      40.957599           0.001046            313.516082
# 3      40.608760           0.001089            326.363646
# 4      41.299982           0.001005            301.398207
# ...          ...                ...                   ...
# 62904   0.000000           0.000000              0.000000
# 62905   0.000000           0.000000              0.000000
# 62906   0.000000           0.000000              0.000000
# 62907   0.000000           0.000000              0.000000
# 62908  39.578304           0.001226            367.472295
#
#        Spectral Flux Density
# 0                -165.968795
# 1                -165.626014
# 2                -165.968795
# 3                -166.317634
# 4                -165.626412
# ...                      ...
# 62904               0.000000
# 62905               0.000000
# 62906               0.000000
# 62907               0.000000
# 62908            -167.348090
#
# [62909 rows x 20 columns]

# %%
 UE_data['Time'].max()
# Out:
# 97.5976955

# %%
 UE_data['Time'].min()
# Out:
# 0.0

# %%
UE_data['Index'].unique()
# Out:
# array([    0,     1,     2, ..., 10482, 10483, 10484], dtype=int64)

# %%
plt.scatter(UE_data['Longitude'], UE_data['Latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.savefig('Figure_3.jpeg')

# %% [markdown]
# # Find the best number of Cluster for our data with Elbow Technique

# %%
wcss = []

for i in range(1, 10):
    kmeans= KMeans(i)
    kmeans.fit(UE_data)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

wcss
# Out:
# [581103264166.607,
#  148872336088.32288,
#  68830467426.6502,
#  40816784182.637634,
#  27850202143.132072,
#  20808412617.895752,
#  16558007264.88787,
#  13802484967.012726,
#  11916594687.660696]

# %%
number_clusters = range(1, 10)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
plt.savefig('plot_MW_vs_LogP.jpeg')

# %% [markdown]
# # 3. Select Features

# %% [markdown]
# # 3.2. Create Clustering Algorithm

# %% [markdown]
# # 1st Method

# %% [markdown]
# Grouping Data point on the basis of similarity : CellType, Latitude and Longitude

# %%
# Select some feature
x = UE_data.iloc[:, 1:4]
x
# Out:
#        CellType  Latitude  Longitude
# 0             0    0.2928  -115.8555
# 1             0    0.2928  -115.8555
# 2             1    0.2928  -115.8555
# 3             1    0.2928  -115.8555
# 4             2    0.2928  -115.8555
# ...         ...       ...        ...
# 62904         0   -1.1051  -118.0414
# 62905         0   -1.1051  -118.0414
# 62906         1   -1.1051  -118.0414
# 62907         1   -1.1051  -118.0414
# 62908         2   -1.1051  -118.0414
#
# [62909 rows x 3 columns]

# %%
# Clustering
kmeans = KMeans(3)

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
# Clustering resuts
identified_clusaters = kmeans.fit_predict(x)
identified_clusaters
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
data_with_clusters = UE_data.copy()
data_with_clusters['Cluster'] = identified_clusaters
data_with_clusters
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2          0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3          0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4          0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# ...      ...       ...       ...        ...        ...         ...        ...
# 62904  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62905  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62906  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62907  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62908  10484         2   -1.1051  -118.0414   0.000000  151.459006 -72.619323
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 2      313.516082       165.600340  165.600340       -135.600340
# 3      326.362599       165.949179  165.949179       -135.949179
# 4      325.250193       165.257957  165.257957       -135.257957
# ...           ...              ...         ...               ...
# 62904    0.000000         0.000000    0.000000          0.000000
# 62905    0.000000         0.000000    0.000000          0.000000
# 62906    0.000000         0.000000    0.000000          0.000000
# 62907    0.000000         0.000000    0.000000          0.000000
# 62908  316.343953       166.979635  166.979635       -136.979635
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 2                      -135.600340    -90.917295   20  52.998799  37.947299
# 3                      -135.949179    -91.266134   20  52.649960  37.598460
# 4                      -135.257957    -90.574912   20  53.341182  38.289683
# ...                            ...           ...  ...        ...        ...
# 62904                     0.000000      0.000000    0   0.000000   0.000000
# 62905                     0.000000      0.000000    0   0.000000   0.000000
# 62906                     0.000000      0.000000    0   0.000000   0.000000
# 62907                     0.000000      0.000000    0   0.000000   0.000000
# 62908                  -136.979635    -92.296591   20  51.619504  36.568004
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
# 2      40.957599           0.001046            313.516082
# 3      40.608760           0.001089            326.363646
# 4      41.299982           0.001005            301.398207
# ...          ...                ...                   ...
# 62904   0.000000           0.000000              0.000000
# 62905   0.000000           0.000000              0.000000
# 62906   0.000000           0.000000              0.000000
# 62907   0.000000           0.000000              0.000000
# 62908  39.578304           0.001226            367.472295
#
#        Spectral Flux Density  Cluster
# 0                -165.968795        1
# 1                -165.626014        1
# 2                -165.968795        1
# 3                -166.317634        1
# 4                -165.626412        1
# ...                      ...      ...
# 62904               0.000000        0
# 62905               0.000000        0
# 62906               0.000000        0
# 62907               0.000000        0
# 62908            -167.348090        0
#
# [62909 rows x 21 columns]

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(data_with_clusters['Longitude'],data_with_clusters['Latitude'], c=data_with_clusters['Cluster'], cmap='rainbow')
legend1 = ax.legend(*scatter.legend_elements(), loc='lower left', title='Clusters')
ax.add_artist(legend1)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.savefig('Figure_4.jpeg')
plt.xlim(-120, -112)
plt.ylim(-2,3)
plt.show()

# %% [markdown]
# # 2nd Method

# %%
# Select some feature
sample_data = UE_data.iloc[0:20000,0:4]
sample_data
# Out:
#        Index  CellType  Latitude  Longitude
# 0          0         0    0.2928  -115.8555
# 1          0         0    0.2928  -115.8555
# 2          0         1    0.2928  -115.8555
# 3          0         1    0.2928  -115.8555
# 4          0         2    0.2928  -115.8555
# ...      ...       ...       ...        ...
# 19995   3332         1   -0.3633  -116.6210
# 19996   3332         2   -0.3633  -116.6210
# 19997   3332         2   -0.3633  -116.6210
# 19998   3333         0   -0.3033  -115.6614
# 19999   3333         0   -0.3033  -115.6614
#
# [20000 rows x 4 columns]

# %%
plt.scatter(sample_data['Latitude'], sample_data['Longitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
km = KMeans(n_clusters=3)
km
# Out:
# KMeans(n_clusters=3)

# %%
y_predicted = km.fit_predict(sample_data[['Latitude','Longitude']])
y_predicted
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
sample_data['cluster'] = y_predicted
sample_data.head()
# Out:
#    Index  CellType  Latitude  Longitude  cluster
# 0      0         0    0.2928  -115.8555        2
# 1      0         0    0.2928  -115.8555        2
# 2      0         1    0.2928  -115.8555        2
# 3      0         1    0.2928  -115.8555        2
# 4      0         2    0.2928  -115.8555        2

# %%
cluster_1 = sample_data[sample_data.cluster == 0]
cluster_2 = sample_data[sample_data.cluster == 1]
cluster_3 = sample_data[sample_data.cluster == 2]

plt.scatter(cluster_1.Longitude, cluster_1['Latitude'], color='green')
plt.scatter(cluster_2.Longitude, cluster_2['Latitude'], color='red')
plt.scatter(cluster_3.Longitude, cluster_3['Latitude'], color='black')
plt.savefig('Figure_5.jpeg')
plt.xlim(-119, -113)
plt.ylim(-2,3)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend("")

# %%
# Select some feature
dendogram_data = UE_data.iloc[0:999,0:4]


Z = hierarchy.linkage(dendogram_data[['Latitude','Longitude']], method='average')
  
plt.figure()
plt.ylabel('Cluster')
plt.xlabel('User Equipment')
plt.title("Dendrograms")
plt.savefig('Figure_6.jpeg')
  
# Dendrogram plotting using linkage matrix
dendrogram = hierarchy.dendrogram(Z)

# %%
# Creating Dendrogram for our data
# max_d = cut-off/ Threshold value
max_d = 5

# Select some feature
dendogram_data = UE_data.iloc[0:99,0:4]
  
Z = hierarchy.linkage(dendogram_data[['Latitude','Longitude']], method='average')
plt.figure()
plt.title("Dendrograms")
plt.ylabel('Cluster')
plt.xlabel('User Equipment')
dendrogram = hierarchy.dendrogram(Z)
  
# Cutting the dendrogram at max_d
plt.axhline(y=max_d, c='k')

# %% [markdown]
# # 4.  Centroids

# %%
cluster_1 = sample_data[sample_data.cluster == 0]
cluster_2 = sample_data[sample_data.cluster == 1]
cluster_3 = sample_data[sample_data.cluster == 2]

plt.scatter(cluster_1.Longitude, cluster_1['Latitude'], color='green') # Target Cell
plt.scatter(cluster_2.Longitude, cluster_2['Latitude'], color='red') # Serving Cell
plt.scatter(cluster_3.Longitude, cluster_3['Latitude'], color='black') # Candidate Cell
plt.savefig('Figure_12.jpeg')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend("")

# %%
sample_data.shape
# Out:
# (20000, 5)

# %% [markdown]
# Centreoid for each cluster

# %%
km.cluster_centers_
# Out:
# array([[   1.24811128, -114.63275951],
#        [  -0.45589892, -117.64306348],
#        [   0.5127348 , -116.18533256]])

# %%
# Center point for the 1st Cluster : Serving Cell
km.cluster_centers_[0:1]
# Out:
# array([[   1.24811128, -114.63275951]])

# %%
centroid_1 = km.cluster_centers_[0:1]
centroid_1_Lat = centroid_1[0][0]
centroid_1_Lon = centroid_1[0][1]
print("Centroid of cluster 1: ", centroid_1_Lat, centroid_1_Lon)
# Out:
# Centroid of cluster 1:  1.248111282984531 -114.63275950864423

# %%
# Center point for the 2nd Cluster : Target Cell
km.cluster_centers_[1:2]
# Out:
# array([[  -0.45589892, -117.64306348]])

# %%
centroid_2 = km.cluster_centers_[1:2]
centroid_2_Lat = centroid_2[0][0]
centroid_2_Lon = centroid_2[0][1]
print("Centroid of cluster 2: ", centroid_2_Lat, centroid_2_Lon)
# Out:
# Centroid of cluster 2:  -0.45589891732283444 -117.64306348425197

# %%
# Center point for the 3rd Cluster : Candidate Cel
km.cluster_centers_[2:3]
# Out:
# array([[   0.5127348 , -116.18533256]])

# %%
centroid_3 = km.cluster_centers_[2:3]
centroid_3_Lat = centroid_3[0][0]
centroid_3_Lon = centroid_3[0][1]
print("Centroid of cluster 3: ", centroid_3_Lat, centroid_3_Lon)
# Out:
# Centroid of cluster 3:  0.5127348016415868 -116.18533255813954

# %%
#sample_data['cluster'] = sample_data['cluster'].replace(0, 'cluster_1')
#sample_data['cluster'] = sample_data['cluster'].replace(1, 'cluster_2')
#sample_data['cluster'] = sample_data['cluster'].replace(2, 'cluster_3')

# %%
sample_data
# Out:
#        Index  CellType  Latitude  Longitude  cluster
# 0          0         0    0.2928  -115.8555        2
# 1          0         0    0.2928  -115.8555        2
# 2          0         1    0.2928  -115.8555        2
# 3          0         1    0.2928  -115.8555        2
# 4          0         2    0.2928  -115.8555        2
# ...      ...       ...       ...        ...      ...
# 19995   3332         1   -0.3633  -116.6210        2
# 19996   3332         2   -0.3633  -116.6210        2
# 19997   3332         2   -0.3633  -116.6210        2
# 19998   3333         0   -0.3033  -115.6614        2
# 19999   3333         0   -0.3033  -115.6614        2
#
# [20000 rows x 5 columns]

# %% [markdown]
# # Data by Cell Type

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(sample_data['Longitude'],sample_data['Latitude'], c=sample_data['cluster'], cmap='rainbow')
legend1 = ax.legend(*scatter.legend_elements(), loc='lower left', title='Clusters')
ax.add_artist(legend1)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.savefig('Figure_4.jpeg')
plt.xlim(-120, -112)
plt.ylim(-2,3)
plt.show()

# %%
Target_Cell = UE_data.loc[UE_data['CellType'] == 1]
Serving_Cell = UE_data.loc[UE_data['CellType'] == 0]
Candidate_Cell = UE_data.loc[UE_data['CellType'] == 2]

# %% [markdown]
# # Candidate_Cell

# %%
Candidate_Cell['Latitude'].min()
# Out:
# -1.53

# %%
Candidate_Cell['Latitude'].max()
# Out:
# 2.2975

# %%
Candidate_Cell['Latitude'].mean()
# Out:
# 0.4421494921073967

# %%
Candidate_Cell['Latitude'].median()
# Out:
# 0.4458

# %% [markdown]
# Calculate the distance between two UE (lat, lon) based on Haversine Formula

# %%
def haversine(lat_centroid, lon_centroid, lat_UE, lon_UE):
    
    # distance between latitudes and longitudes
    dLat = (lat_UE - lat_centroid) * math.pi / 180.0
    dLon = (lon_UE - lon_centroid) * math.pi / 180.0
    
    # Convert to radians
    lat_centroid = (lat_centroid) * math.pi / 180.0
    lat_UE = (lat_UE) * math.pi / 180.0
    
    # Apply formula
    a = (pow(math.sin(dLat / 2), 2) + pow(math.sin(dLon / 2), 2) * math.cos(lat_centroid) * math.cos(lat_UE))
    radius = 6371 # Earth Radius
    c = 2 * math.asin(math.sqrt(a))
    
    return radius * c

lat_centroid = 51.5007
lon_centroid = 0.1246
lat_UE = 40.6892
lon_UE = 74.0445

print(haversine(lat_centroid, lon_centroid, lat_UE, lon_UE), "KM")
# Out:
# 5574.840456848555 KM

# %%
Candidate_Cell.head(3)
# Out:
#     Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 4       0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# 5       0         2    0.2928  -115.8555  48.791738  164.164691 -66.270079
# 10      1         2   -0.8417  -118.5595   0.000000  183.799629 -68.340436
#
#          Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 4   325.250193       165.257957  165.257957       -135.257957
# 5   330.029127       167.580390  167.580390       -137.580390
# 10  325.295104       167.435246  167.435246       -137.435246
#
#     Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 4                   -135.257957    -90.574912   20  53.341182  38.289683
# 5                   -137.580390    -92.897345   20  51.018749  35.967249
# 10                  -137.435246    -92.752201   20  51.163893  36.112393
#
#         Eb/No  Propagation Delay  Propagation Distance  Spectral Flux Density
# 4   41.299982           0.001005            301.398207            -165.626412
# 5   38.977549           0.001314            393.787877            -167.948845
# 10  39.122693           0.001292            387.262225            -167.803701

# %%
# Candidate centroid =    centroid_3_Lat, centroid_3_Lon
lat_centroid = centroid_3_Lat
lon_centroid = centroid_3_Lon

def haversine(lat_centroid, lon_centroid, lat_UE, lon_UE):
    
    # distance between latitudes and longitudes
    dLat = (lat_UE - lat_centroid) * math.pi / 180.0
    dLon = (lon_UE - lon_centroid) * math.pi / 180.0
    
    # Convert to radians
    lat_centroid = (lat_centroid) * math.pi / 180.0
    lat_UE = (lat_UE) * math.pi / 180.0
    
    # Apply formula
    a = (pow(math.sin(dLat / 2), 2) + pow(math.sin(dLon / 2), 2) * math.cos(lat_centroid) * math.cos(lat_UE))
    radius = 6371 # Earth Radius
    c = 2 * math.asin(math.sqrt(a))
    
    return radius * c


lat_UE = 0.-0.8417
lon_UE = -118.5595

print(haversine(lat_centroid, lon_centroid, lat_UE, lon_UE), "KM")
# Out:
# 303.92760445393213 KM

# %% [markdown]
# Compute the Haversine for all User Equiment in Cell Type 0

# %%
# Candidate centroid =    centroid_3_Lat, centroid_3_Lon
lat_centroid = centroid_3_Lat
lon_centroid = centroid_3_Lon

def haversine(row):
    lat_centroid = centroid_3_Lat
    lon_centroid = centroid_3_Lon
    lat_UE = row['Latitude']
    lon_UE = row['Longitude']
    
    lat_centroid, lon_centroid, lat_UE, lon_UE = map(radians, [lat_centroid, lon_centroid, lat_UE, lon_UE])
    dlat = lat_UE - lat_centroid
    dlon = lon_UE - lon_centroid
    
    a = sin(dlat / 2)**2 + cos(lat_centroid) * cos(lat_UE) * sin(dlon / 2)**2
    c = 2 * arcsin(sqrt(a))
    d = 6371 * c # Km
    
    return d

Candidate_Cell['distance'] = Candidate_Cell.apply(lambda row: haversine(row), axis=1)
# Out:
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_12436\841968176.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Candidate_Cell['distance'] = Candidate_Cell.apply(lambda row: haversine(row), axis=1)

# %%
Candidate_Cell['distance'].min()
# Out:
# 0.6395264238196291

# %%
Candidate_Cell['distance'].max()
# Out:
# 350.8202583967184

# %%
Candidate_Cell['distance'].median()
# Out:
# 152.11358906526317

# %%
Candidate_Cell
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 4          0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# 5          0         2    0.2928  -115.8555  48.791738  164.164691 -66.270079
# 10         1         2   -0.8417  -118.5595   0.000000  183.799629 -68.340436
# 11         1         2   -0.8417  -118.5595   1.946600  183.236699 -66.229885
# 16         2         2    0.4267  -117.2159   0.000000  322.691828 -71.889467
# ...      ...       ...       ...        ...        ...         ...        ...
# 62896  10482         2   -0.1780  -116.0009   9.386000   32.827006 -68.208320
# 62897  10482         2   -0.1780  -116.0009  40.496971  146.716345 -66.411289
# 62902  10483         2   -0.4869  -118.1291   0.000000  198.366132 -78.352231
# 62903  10483         2   -0.4869  -118.1291  10.731578  187.420567 -66.240581
# 62908  10484         2   -1.1051  -118.0414   0.000000  151.459006 -72.619323
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 4      325.250193       165.257957  165.257957       -135.257957
# 5      330.029127       167.580390  167.580390       -137.580390
# 10     325.295104       167.435246  167.435246       -137.435246
# 11     330.636563       167.628313  167.628313       -137.628313
# 16     317.699402       165.475679  165.475679       -135.475679
# ...           ...              ...         ...               ...
# 62896  325.588878       165.444653  165.444653       -135.444653
# 62897  329.806225       167.452252  167.452252       -137.452252
# 62902  307.836519       166.599588  166.599588       -136.599588
# 62903  330.581867       167.620515  167.620515       -137.620515
# 62908  316.343953       166.979635  166.979635       -136.979635
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 4                      -135.257957    -90.574912   20  53.341182  38.289683
def haversine(row):
    lat_centroid = centroid_1_Lat
    lon_centroid = centroid_1_Lon
    lat_UE = row['Latitude']
    lon_UE = row['Longitude']
    
    lat_centroid, lon_centroid, lat_UE, lon_UE = map(radians, [lat_centroid, lon_centroid, lat_UE, lon_UE])
    dlat = lat_UE - lat_centroid
    dlon = lon_UE - lon_centroid
    
    a = sin(dlat / 2)**2 + cos(lat_centroid) * cos(lat_UE) * sin(dlon / 2)**2
    c = 2 * arcsin(sqrt(a))
    d = 6371 * c # Km
    
    return d

Target_Cell['distance'] = Target_Cell.apply(lambda row: haversine(row), axis=1)
# Out:
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_12436\3994972881.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Target_Cell['distance'] = Target_Cell.apply(lambda row: haversine(row), axis=1)

# %%
Target_Cell.head(4)
# Out:
#    Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 2      0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3      0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 8      1         1   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 9      1         1   -0.8417  -118.5595   0.000000    0.000000   0.000000
#
#         Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 2  313.516082       165.600340  165.600340       -135.600340
# 3  326.362599       165.949179  165.949179       -135.949179
# 8    0.000000         0.000000    0.000000          0.000000
# 9    0.000000         0.000000    0.000000          0.000000
#
#    Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 2                  -135.600340    -90.917295   20  52.998799  37.947299
# 3                  -135.949179    -91.266134   20  52.649960  37.598460
# 8                     0.000000      0.000000    0   0.000000   0.000000
# 9                     0.000000      0.000000    0   0.000000   0.000000
#
#        Eb/No  Propagation Delay  Propagation Distance  Spectral Flux Density  \
# 2  40.957599           0.001046            313.516082            -165.968795
# 3  40.608760           0.001089            326.363646            -166.317634
# 8   0.000000           0.000000              0.000000               0.000000
# 9   0.000000           0.000000              0.000000               0.000000
#
#      distance
# 2  172.528128
# 3  172.528128
# 8  494.594964
# 9  494.594964

# %%
Target_Cell['distance'].min()
# Out:
# 3.0268591815879566

# %%
Target_Cell['distance'].max()
# Out:
# 500.7663750304292

# %%
Target_Cell['distance'].median()
# Out:
# 196.23642505369384

# %%
#Create the Target
# What are these classes
# UE ready for Handover (HO) distance >= 197Km : 1
# UE Not ready for Handover (HO) distance < 197Km : 0

targets_t = np.where(Target_Cell['distance'] > 197, 1, 0)
Target_Cell['Handover_Ready'] = targets_t
# Out:
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_12436\480488350.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Target_Cell['Handover_Ready'] = targets_t

# %%
Target_Cell
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 2          0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3          0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 8          1         1   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 9          1         1   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 14         2         1    0.4267  -117.2159   0.000000  235.712499 -76.442666
# ...      ...       ...       ...        ...        ...         ...        ...
# 62895  10482         1   -0.1780  -116.0009  22.307000  147.119685 -67.301100
# 62900  10483         1   -0.4869  -118.1291   0.000000    0.000000   0.000000
# 62901  10483         1   -0.4869  -118.1291   0.000000    0.000000   0.000000
# 62906  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62907  10484         1   -1.1051  -118.0414   0.000000    0.000000   0.000000
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 2      313.516082       165.600340  165.600340       -135.600340
# 3      326.362599       165.949179  165.949179       -135.949179
# 8        0.000000         0.000000    0.000000          0.000000
# 9        0.000000         0.000000    0.000000          0.000000
# 14     309.048598       165.475679  165.475679       -135.475679
# ...           ...              ...         ...               ...
# 62895  326.459370       165.951726  165.951726       -135.951726
# 62900    0.000000         0.000000    0.000000          0.000000
# 62901    0.000000         0.000000    0.000000          0.000000
# 62906    0.000000         0.000000    0.000000          0.000000
# 62907    0.000000         0.000000    0.000000          0.000000
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 2                      -135.600340    -90.917295   20  52.998799  37.947299
# 3                      -135.949179    -91.266134   20  52.649960  37.598460
# 8                         0.000000      0.000000    0   0.000000   0.000000
# 9                         0.000000      0.000000    0   0.000000   0.000000
# 14                     -135.475679    -90.792634   20  53.123460  38.071960
# ...                            ...           ...  ...        ...        ...
# 62895                  -135.951726    -91.268681   20  52.647413  37.595913
# 62900                     0.000000      0.000000    0   0.000000   0.000000
# 62901                     0.000000      0.000000    0   0.000000   0.000000
# 62906                     0.000000      0.000000    0   0.000000   0.000000
# 62907                     0.000000      0.000000    0   0.000000   0.000000
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 2      40.957599           0.001046            313.516082
# 3      40.608760           0.001089            326.363646
# 8       0.000000           0.000000              0.000000
# 9       0.000000           0.000000              0.000000
# 14     41.082260           0.001031            309.048598
# ...          ...                ...                   ...
# 62895  40.606213           0.001089            326.459370
# 62900   0.000000           0.000000              0.000000
# 62901   0.000000           0.000000              0.000000
# 62906   0.000000           0.000000              0.000000
# 62907   0.000000           0.000000              0.000000
#
#        Spectral Flux Density    distance  Handover_Ready
# 2                -165.968795  172.528128               0
# 3                -166.317634  172.528128               0
# 8                   0.000000  494.594964               1
# 9                   0.000000  494.594964               1
# 14               -165.844134  301.372951               1
# ...                      ...         ...             ...
# 62895            -166.320181  219.742724               1
# 62900               0.000000  433.990638               1
# 62901               0.000000  433.990638               1
# 62906               0.000000  460.550833               1
# 62907               0.000000  460.550833               1
#
# [20970 rows x 22 columns]

# %% [markdown]
# # Serving Cell

# %%
Serving_Cell.head(2)
# Out:
#    Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0      0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1      0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
#
#         Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0  304.330261       165.600340  165.600340       -135.600340
# 1  325.251116       165.257559  165.257559       -135.257559
#
#    Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                  -135.600340    -90.917295   20  52.998799  37.947299
# 1                  -135.257559    -90.574514   20  53.341580  38.290080
#
#        Eb/No  Propagation Delay  Propagation Distance  Spectral Flux Density
# 0  40.957599           0.001046            313.516082            -165.968795
# 1  41.300380           0.001005            301.384403            -165.626014

# %%
# Serving Cell centroid =  0.51234966, -116.1918463
lat_centroid = centroid_1_Lat
lon_centroid = centroid_1_Lon

def haversine(row):
    lat_centroid = centroid_2_Lat
    lon_centroid = centroid_2_Lon
    lat_UE = row['Latitude']
    lon_UE = row['Longitude']
    
    lat_centroid, lon_centroid, lat_UE, lon_UE = map(radians, [lat_centroid, lon_centroid, lat_UE, lon_UE])
    dlat = lat_UE - lat_centroid
    dlon = lon_UE - lon_centroid
    
    a = sin(dlat / 2)**2 + cos(lat_centroid) * cos(lat_UE) * sin(dlon / 2)**2
    c = 2 * arcsin(sqrt(a))
    d = 6371 * c # Km
    
    return d

Serving_Cell['distance'] = Serving_Cell.apply(lambda row: haversine(row), axis=1)
# Out:
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_12436\1330579970.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Serving_Cell['distance'] = Serving_Cell.apply(lambda row: haversine(row), axis=1)

# %%
Serving_Cell
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 6          1         0   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 7          1         0   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 12         2         0    0.4267  -117.2159   0.000000    0.000000   0.000000
# ...      ...       ...       ...        ...        ...         ...        ...
# 62893  10482         0   -0.1780  -116.0009   4.261563  147.800978 -68.215282
# 62898  10483         0   -0.4869  -118.1291   0.000000    0.000000   0.000000
# 62899  10483         0   -0.4869  -118.1291   0.000000    0.000000   0.000000
# 62904  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62905  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 6        0.000000         0.000000    0.000000          0.000000
# 7        0.000000         0.000000    0.000000          0.000000
# 12       0.000000         0.000000    0.000000          0.000000
# ...           ...              ...         ...               ...
# 62893  325.586581       165.436784  165.436784       -135.436784
# 62898    0.000000         0.000000    0.000000          0.000000
# 62899    0.000000         0.000000    0.000000          0.000000
# 62904    0.000000         0.000000    0.000000          0.000000
# 62905    0.000000         0.000000    0.000000          0.000000
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 6                         0.000000      0.000000    0   0.000000   0.000000
# 7                         0.000000      0.000000    0   0.000000   0.000000
# 12                        0.000000      0.000000    0   0.000000   0.000000
# ...                            ...           ...  ...        ...        ...
# 62893                  -135.436784    -90.753739   20  53.162355  38.110855
# 62898                     0.000000      0.000000    0   0.000000   0.000000
# 62899                     0.000000      0.000000    0   0.000000   0.000000
# 62904                     0.000000      0.000000    0   0.000000   0.000000
# 62905                     0.000000      0.000000    0   0.000000   0.000000
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
# 6       0.000000           0.000000              0.000000
# 7       0.000000           0.000000              0.000000
# 12      0.000000           0.000000              0.000000
# ...          ...                ...                   ...
# 62893  41.121155           0.001026            307.667782
# 62898   0.000000           0.000000              0.000000
# 62899   0.000000           0.000000              0.000000
# 62904   0.000000           0.000000              0.000000
# 62905   0.000000           0.000000              0.000000
#
#        Spectral Flux Density    distance
# 0                -165.968795  215.496839
# 1                -165.626014  215.496839
# 6                   0.000000  110.558600
# 7                   0.000000  110.558600
# 12                  0.000000  109.030346
# ...                      ...         ...
# 62893            -165.805239  185.193503
# 62898               0.000000   54.152793
# 62899               0.000000   54.152793
# 62904               0.000000   84.691044
# 62905               0.000000   84.691044
#
# [20970 rows x 21 columns]

# %%
Serving_Cell['distance'].min()
# Out:
# 2.0905445817246804

# %%
Serving_Cell['distance'].max()
# Out:
# 545.4197392260543

# %%
Serving_Cell['distance'].median()
# Out:
# 216.5280396435605

# %%
#Create the Target
# What are these classes
# UE ready for Handover (HO) distance >= 216Km : 1
# UE Not ready for Handover (HO) distance < 216Km : 0

targets_s = np.where(Target_Cell['distance'] > 216, 1, 0)
Serving_Cell['Handover_Ready'] = targets_s
# Out:
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_12436\3919117270.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Serving_Cell['Handover_Ready'] = targets_s

# %%
Serving_Cell
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 6          1         0   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 7          1         0   -0.8417  -118.5595   0.000000    0.000000   0.000000
# 12         2         0    0.4267  -117.2159   0.000000    0.000000   0.000000
# ...      ...       ...       ...        ...        ...         ...        ...
# 62893  10482         0   -0.1780  -116.0009   4.261563  147.800978 -68.215282
# 62898  10483         0   -0.4869  -118.1291   0.000000    0.000000   0.000000
# 62899  10483         0   -0.4869  -118.1291   0.000000    0.000000   0.000000
# 62904  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
# 62905  10484         0   -1.1051  -118.0414   0.000000    0.000000   0.000000
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 6        0.000000         0.000000    0.000000          0.000000
# 7        0.000000         0.000000    0.000000          0.000000
# 12       0.000000         0.000000    0.000000          0.000000
# ...           ...              ...         ...               ...
# 62893  325.586581       165.436784  165.436784       -135.436784
# 62898    0.000000         0.000000    0.000000          0.000000
# 62899    0.000000         0.000000    0.000000          0.000000
# 62904    0.000000         0.000000    0.000000          0.000000
# 62905    0.000000         0.000000    0.000000          0.000000
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 6                         0.000000      0.000000    0   0.000000   0.000000
# 7                         0.000000      0.000000    0   0.000000   0.000000
# 12                        0.000000      0.000000    0   0.000000   0.000000
# ...                            ...           ...  ...        ...        ...
# 62893                  -135.436784    -90.753739   20  53.162355  38.110855
# 62898                     0.000000      0.000000    0   0.000000   0.000000
# 62899                     0.000000      0.000000    0   0.000000   0.000000
# 62904                     0.000000      0.000000    0   0.000000   0.000000
# 62905                     0.000000      0.000000    0   0.000000   0.000000
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
#
# 65             -167.729674  228.812340               1
# 70             -165.945805  148.829587               0
# 71             -167.892114  148.829587               0
# 76             -167.208478  259.776350               1
# 77             -167.968880  259.776350               1
# 82             -165.736609   57.214786               0
# 83             -167.926804   57.214786               0
# 88             -165.615992   85.590234               0
# 89             -167.951544   85.590234               0
# 94             -166.309224  114.666814               0
# 95             -167.565355  114.666814               0
# 100            -166.121508  108.813333               0
# 101            -167.596357  108.813333               0
# 106            -165.760566   89.278525               0
# 107            -167.916122   89.278525               0
# 112            -165.620692   45.203678               0
# 113            -167.976663   45.203678               0
# 118            -165.578609  282.963026               1
# 119            -167.964726  282.963026               1
# 124            -165.658667   68.619036               0
# 125            -167.966722   68.619036               0
# 130            -165.721522  162.311593               1
# 131            -167.918393  162.311593               1
# 136            -166.571695  201.348605               1
# 137            -167.828449  201.348605               1
# 142            -166.384399  193.710284               1
# 143            -167.979822  193.710284               1
# 148            -166.911411  235.970156               1
# 149            -167.413630  235.970156               1

# %%
classifier_UE_data.shape
# Out:
# (62909, 22)

# %%
classifier_UE_data['Index'].unique()
# Out:
# array([    0,     1,     2, ..., 10482, 10483, 10484], dtype=int64)

# %%
classifier_UE_data = classifier_UE_data.loc[classifier_UE_data['Index'].unique()]

# %%
classifier_UE_data
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2          0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3          0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4          0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# ...      ...       ...       ...        ...        ...         ...        ...
# 10480   1746         2    0.8053  -116.1382  13.136000  342.320547 -68.324816
# 10481   1746         2    0.8053  -116.1382  49.001000  192.394737 -66.253986
# 10482   1747         0   -1.0214  -116.4345   0.000000    0.000000   0.000000
# 10483   1747         0   -1.0214  -116.4345   0.000000    0.000000   0.000000
# 10484   1747         1   -1.0214  -116.4345   0.000000    0.000000   0.000000
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 2      313.516082       165.600340  165.600340       -135.600340
# 3      326.362599       165.949179  165.949179       -135.949179
# 4      325.250193       165.257957  165.257957       -135.257957
# ...           ...              ...         ...               ...
# 10480  325.298947       165.285407  165.285407       -135.285407
# 10481  330.072786       167.595458  167.595458       -137.595458
# 10482    0.000000         0.000000    0.000000          0.000000
# 10483    0.000000         0.000000    0.000000          0.000000
# 10484    0.000000         0.000000    0.000000          0.000000
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 2                      -135.600340    -90.917295   20  52.998799  37.947299
# 3                      -135.949179    -91.266134   20  52.649960  37.598460
# 4                      -135.257957    -90.574912   20  53.341182  38.289683
# ...                            ...           ...  ...        ...        ...
# 10480                  -135.285407    -90.602362   20  53.313732  38.262232
# 10481                  -137.595458    -92.912414   20  51.003681  35.952181
# 10482                     0.000000      0.000000    0   0.000000   0.000000
# 10483                     0.000000      0.000000    0   0.000000   0.000000
# 10484                     0.000000      0.000000    0   0.000000   0.000000
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
# 2      40.957599           0.001046            313.516082
# 3      40.608760           0.001089            326.363646
# 4      41.299982           0.001005            301.398207
# ...          ...                ...                   ...
# 10480  41.272532           0.001009            302.352228
# 10481  38.962481           0.001316            394.471605
# 10482   0.000000           0.000000              0.000000
# 10483   0.000000           0.000000              0.000000
# 10484   0.000000           0.000000              0.000000
#
#        Spectral Flux Density    distance  Handover_Ready
# 0                -165.968795  215.496839               0
# 1                -165.626014  215.496839               0
# 2                -165.968795  172.528128               0
# 3                -166.317634  172.528128               0
# 4                -165.626412   44.080805               0
# ...                      ...         ...             ...
# 10480            -165.653862   32.951163               0
# 10481            -167.963913   32.951163               0
# 10482               0.000000  148.359310               1
# 10483               0.000000  148.359310               1
# 10484               0.000000  322.206619               1
#
# [10485 rows x 22 columns]

# %%
classifier_UE_data['Time'].max()
# Out:
# 97.5976955

# %%
classifier_UE_data.shape
# Out:
# (10485, 22)

# %%
classifier_UE_data
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 0          0         0    0.2928  -115.8555   0.000000  143.355488 -81.956980
# 1          0         0    0.2928  -115.8555  12.115721  166.458699 -68.345139
# 2          0         1    0.2928  -115.8555   0.000000   16.609009 -73.525173
# 3          0         1    0.2928  -115.8555  30.382608  165.204452 -67.304924
# 4          0         2    0.2928  -115.8555  12.907000   13.626764 -68.343815
# ...      ...       ...       ...        ...        ...         ...        ...
# 10480   1746         2    0.8053  -116.1382  13.136000  342.320547 -68.324816
# 10481   1746         2    0.8053  -116.1382  49.001000  192.394737 -66.253986
# 10482   1747         0   -1.0214  -116.4345   0.000000    0.000000   0.000000
# 10483   1747         0   -1.0214  -116.4345   0.000000    0.000000   0.000000
# 10484   1747         1   -1.0214  -116.4345   0.000000    0.000000   0.000000
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 0      304.330261       165.600340  165.600340       -135.600340
# 1      325.251116       165.257559  165.257559       -135.257559
# 2      313.516082       165.600340  165.600340       -135.600340
# 3      326.362599       165.949179  165.949179       -135.949179
# 4      325.250193       165.257957  165.257957       -135.257957
# ...           ...              ...         ...               ...
# 10480  325.298947       165.285407  165.285407       -135.285407
# 10481  330.072786       167.595458  167.595458       -137.595458
# 10482    0.000000         0.000000    0.000000          0.000000
# 10483    0.000000         0.000000    0.000000          0.000000
# 10484    0.000000         0.000000    0.000000          0.000000
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 0                      -135.600340    -90.917295   20  52.998799  37.947299
# 1                      -135.257559    -90.574514   20  53.341580  38.290080
# 2                      -135.600340    -90.917295   20  52.998799  37.947299
# 3                      -135.949179    -91.266134   20  52.649960  37.598460
# 4                      -135.257957    -90.574912   20  53.341182  38.289683
# ...                            ...           ...  ...        ...        ...
# 10480                  -135.285407    -90.602362   20  53.313732  38.262232
# 10481                  -137.595458    -92.912414   20  51.003681  35.952181
# 10482                     0.000000      0.000000    0   0.000000   0.000000
# 10483                     0.000000      0.000000    0   0.000000   0.000000
# 10484                     0.000000      0.000000    0   0.000000   0.000000
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 0      40.957599           0.001046            313.516082
# 1      41.300380           0.001005            301.384403
# 2      40.957599           0.001046            313.516082
# 3      40.608760           0.001089            326.363646
# 4      41.299982           0.001005            301.398207
# ...          ...                ...                   ...
# 10480  41.272532           0.001009            302.352228
# 10481  38.962481           0.001316            394.471605
# 10482   0.000000           0.000000              0.000000
# 10483   0.000000           0.000000              0.000000
# 10484   0.000000           0.000000              0.000000
#
#        Spectral Flux Density    distance  Handover_Ready
# 0                -165.968795  215.496839               0
# 1                -165.626014  215.496839               0
# 2                -165.968795  172.528128               0
# 3                -166.317634  172.528128               0
# 4                -165.626412   44.080805               0
# ...                      ...         ...             ...
# 10480            -165.653862   32.951163               0
# 10481            -167.963913   32.951163               0
# 10482               0.000000  148.359310               1
# 10483               0.000000  148.359310               1
# 10484               0.000000  322.206619               1
#
# [10485 rows x 22 columns]

# %%
classifier_UE_data['Handover_Ready'].unique()
# Out:
# array([0, 1])

# %%
classifier_UE_data['Handover_Ready'].value_counts()
# Out:
# 1    5271
# 0    5214
# Name: Handover_Ready, dtype: int64

# %%
#targets.sum() / targets.shape[0]
classifier_UE_data['Handover_Ready'].sum() / classifier_UE_data.shape[0]
# Out:
# 0.5027181688125895

# %%
# Plot the dataset after the undersampling
plt.figure(figsize=(4, 4))
sns.countplot(x=classifier_UE_data['Handover_Ready'])
plt.title('Balanced Classes')
plt.show()

# %% [markdown]
# # Fix Imbalanced Dataset

# %%
# Shuffle the Dataset
shuffled_UE_data = classifier_UE_data.sample(frac=1, random_state=4)

# %%
# Put all the Ready class in a separate dataset
Ready = shuffled_UE_data.loc[shuffled_UE_data['Handover_Ready'] == 1]

# %%
# Randomly select 101196 observations from the Non Ready (majority Class)
Non_Ready = shuffled_UE_data.loc[shuffled_UE_data['Handover_Ready'] == 0].sample(n=5113, random_state=42)

# %%
# Concatenate both Dataframmes again
normalized_UE_data = pd.concat([Ready, Non_Ready])

# %%
normalized_UE_data
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 174       29         0   -0.8174  -118.2951   0.000000    0.000000   0.000000
# 5787     964         1    0.5569  -117.6202   1.594764  227.984889 -67.300835
# 7086    1181         0    0.9696  -116.6822   0.000000  226.730625 -69.050211
# 2236     372         2    0.1148  -114.5386  43.912435   78.489753 -67.537420
# 5883     980         1    0.6593  -117.3924   6.156000  225.880460 -67.300826
# ...      ...       ...       ...        ...        ...         ...        ...
# 3338     556         1    1.3795  -115.6594   8.159385  327.364664 -67.300003
# 10451   1741         2    0.0346  -116.8009  33.973590  176.630073 -66.229582
# 9530    1588         1    1.6133  -115.4167  14.327000  322.660679 -67.300467
# 7882    1313         2    0.0167  -116.8996   0.000000  357.904156 -73.758022
# 7426    1237         2   -0.3377  -116.2413   4.856000   33.801208 -68.201441
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 174      0.000000         0.000000    0.000000          0.000000
# 5787   326.565943       165.954572  165.954572       -135.954572
# 7086   323.645845       165.637265  165.637265       -135.637265
# 2236   326.848406       166.275026  166.275026       -136.275026
# 5883   326.559660       165.954394  165.954394       -135.954394
# ...           ...              ...         ...               ...
# 3338   326.566819       165.954609  165.954609       -135.954609
# 10451  330.393326       167.623095  167.623095       -137.623095
# 9530   326.542008       165.953924  165.953924       -135.953924
# 7882   314.345639       165.268636  165.268636       -135.268636
# 7426   325.619043       165.457998  165.457998       -135.457998
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 174                       0.000000      0.000000    0   0.000000   0.000000
# 5787                   -135.954572    -91.271528   20  52.644567  37.593067
# 7086                   -135.637265    -90.954220   20  52.961874  37.910374
# 2236                   -136.275026    -91.591981   20  52.324113  37.272613
# 5883                   -135.954394    -91.271349   20  52.644745  37.593245
# ...                            ...           ...  ...        ...        ...
# 3338                   -135.954609    -91.271564   20  52.644530  37.593030
# 10451                  -137.623095    -92.940050   20  50.976044  35.924544
# 9530                   -135.953924    -91.270880   20  52.645214  37.593715
# 7882                   -135.268636    -90.585591   20  53.330503  38.279003
# 7426                   -135.457998    -90.774954   20  53.141140  38.089641
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 174     0.000000           0.000000              0.000000
# 5787   40.603367           0.001089            326.566361
# 7086   40.920674           0.001050            314.851725
# 2236   40.282913           0.001130            338.839574
# 5883   40.603545           0.001089            326.559660
# ...          ...                ...                   ...
# 3338   40.603330           0.001089            326.567731
# 10451  38.934844           0.001320            395.728729
# 9530   40.604015           0.001089            326.542008
# 7882   41.289303           0.001007            301.769000
# 7426   41.099941           0.001029            308.420158
#
#        Spectral Flux Density    distance  Handover_Ready
# 174                 0.000000   82.896601               1
# 5787             -166.323027  340.921736               1
# 7086             -166.005720  191.153090               1
# 2236             -166.643481  188.375758               1
# 5883             -166.322849  313.722195               1
# ...                      ...         ...             ...
# 3338             -166.323064  115.058497               0
# 10451            -167.991550   86.669674               0
# 9530             -166.322380   96.139592               0
# 7882             -165.637091   96.695765               0
# 7426             -165.826454   94.768589               0
#
# [10384 rows x 22 columns]

# %%
normalized_UE_data['Handover_Ready'].value_counts()
# Out:
# 1    5271
# 0    5113
# Name: Handover_Ready, dtype: int64

# %%
#targets.sum() / targets.shape[0]
normalized_UE_data['Handover_Ready'].sum() / normalized_UE_data.shape[0]
# Out:
# 0.5076078582434514

# %%
# Plot the dataset after the undersampling
plt.figure(figsize=(4, 4))
sns.countplot(x=normalized_UE_data['Handover_Ready'])
plt.title('Balanced Classes')
plt.show()

# %% [markdown]
# # Select the inputs for the Regression

# %%
inputs = normalized_UE_data.iloc[:, 0:21]
target = normalized_UE_data['Handover_Ready']

# %%
inputs
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 174       29         0   -0.8174  -118.2951   0.000000    0.000000   0.000000
# 5787     964         1    0.5569  -117.6202   1.594764  227.984889 -67.300835
# 7086    1181         0    0.9696  -116.6822   0.000000  226.730625 -69.050211
# 2236     372         2    0.1148  -114.5386  43.912435   78.489753 -67.537420
# 5883     980         1    0.6593  -117.3924   6.156000  225.880460 -67.300826
# ...      ...       ...       ...        ...        ...         ...        ...
# 3338     556         1    1.3795  -115.6594   8.159385  327.364664 -67.300003
# 10451   1741         2    0.0346  -116.8009  33.973590  176.630073 -66.229582
# 9530    1588         1    1.6133  -115.4167  14.327000  322.660679 -67.300467
# 7882    1313         2    0.0167  -116.8996   0.000000  357.904156 -73.758022
# 7426    1237         2   -0.3377  -116.2413   4.856000   33.801208 -68.201441
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 174      0.000000         0.000000    0.000000          0.000000
# 5787   326.565943       165.954572  165.954572       -135.954572
# 7086   323.645845       165.637265  165.637265       -135.637265
# 2236   326.848406       166.275026  166.275026       -136.275026
# 5883   326.559660       165.954394  165.954394       -135.954394
# ...           ...              ...         ...               ...
# 3338   326.566819       165.954609  165.954609       -135.954609
# 10451  330.393326       167.623095  167.623095       -137.623095
# 9530   326.542008       165.953924  165.953924       -135.953924
# 7882   314.345639       165.268636  165.268636       -135.268636
# 7426   325.619043       165.457998  165.457998       -135.457998
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 174                       0.000000      0.000000    0   0.000000   0.000000
# 5787                   -135.954572    -91.271528   20  52.644567  37.593067
# 7086                   -135.637265    -90.954220   20  52.961874  37.910374
# 2236                   -136.275026    -91.591981   20  52.324113  37.272613
# 5883                   -135.954394    -91.271349   20  52.644745  37.593245
# ...                            ...           ...  ...        ...        ...
# 3338                   -135.954609    -91.271564   20  52.644530  37.593030
# 10451                  -137.623095    -92.940050   20  50.976044  35.924544
# 9530                   -135.953924    -91.270880   20  52.645214  37.593715
# 7882                   -135.268636    -90.585591   20  53.330503  38.279003
# 7426                   -135.457998    -90.774954   20  53.141140  38.089641
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 174     0.000000           0.000000              0.000000
# 5787   40.603367           0.001089            326.566361
# 7086   40.920674           0.001050            314.851725
# 2236   40.282913           0.001130            338.839574
# 5883   40.603545           0.001089            326.559660
# ...          ...                ...                   ...
# 3338   40.603330           0.001089            326.567731
# 10451  38.934844           0.001320            395.728729
# 9530   40.604015           0.001089            326.542008
# 7882   41.289303           0.001007            301.769000
# 7426   41.099941           0.001029            308.420158
#
#        Spectral Flux Density    distance
# 174                 0.000000   82.896601
# 5787             -166.323027  340.921736
# 7086             -166.005720  191.153090
# 2236             -166.643481  188.375758
# 5883             -166.322849  313.722195
# ...                      ...         ...
# 3338             -166.323064  115.058497
# 10451            -167.991550   86.669674
# 9530             -166.322380   96.139592
# 7882             -165.637091   96.695765
# 7426             -165.826454   94.768589
#
# [10384 rows x 21 columns]

# %%
target
# Out:
# 174      1
# 5787     1
# 7086     1
# 2236     1
# 5883     1
#         ..
# 3338     0
# 10451    0
# 9530     0
# 7882     0
# 7426     0
# Name: Handover_Ready, Length: 10384, dtype: int32

# %% [markdown]
# # Standardize The Data

# %%
unscalled_inputs = normalized_UE_data.iloc[:,:-1]

# %%
unscalled_inputs
# Out:
#        Index  CellType  Latitude  Longitude       Time     Azimuth  Elevation  \
# 174       29         0   -0.8174  -118.2951   0.000000    0.000000   0.000000
# 5787     964         1    0.5569  -117.6202   1.594764  227.984889 -67.300835
# 7086    1181         0    0.9696  -116.6822   0.000000  226.730625 -69.050211
# 2236     372         2    0.1148  -114.5386  43.912435   78.489753 -67.537420
# 5883     980         1    0.6593  -117.3924   6.156000  225.880460 -67.300826
# ...      ...       ...       ...        ...        ...         ...        ...
# 3338     556         1    1.3795  -115.6594   8.159385  327.364664 -67.300003
# 10451   1741         2    0.0346  -116.8009  33.973590  176.630073 -66.229582
# 9530    1588         1    1.6133  -115.4167  14.327000  322.660679 -67.300467
# 7882    1313         2    0.0167  -116.8996   0.000000  357.904156 -73.758022
# 7426    1237         2   -0.3377  -116.2413   4.856000   33.801208 -68.201441
#
#             Range  Free Space Loss   Prop Loss  Rcvd. Iso. Power  \
# 174      0.000000         0.000000    0.000000          0.000000
# 5787   326.565943       165.954572  165.954572       -135.954572
# 7086   323.645845       165.637265  165.637265       -135.637265
# 2236   326.848406       166.275026  166.275026       -136.275026
# 5883   326.559660       165.954394  165.954394       -135.954394
# ...           ...              ...         ...               ...
# 3338   326.566819       165.954609  165.954609       -135.954609
# 10451  330.393326       167.623095  167.623095       -137.623095
# 9530   326.542008       165.953924  165.953924       -135.953924
# 7882   314.345639       165.268636  165.268636       -135.268636
# 7426   325.619043       165.457998  165.457998       -135.457998
#
#        Carrier Power at Rcvr Input  Flux Density  g/T       C/No        C/N  \
# 174                       0.000000      0.000000    0   0.000000   0.000000
# 5787                   -135.954572    -91.271528   20  52.644567  37.593067
# 7086                   -135.637265    -90.954220   20  52.961874  37.910374
# 2236                   -136.275026    -91.591981   20  52.324113  37.272613
# 5883                   -135.954394    -91.271349   20  52.644745  37.593245
# ...                            ...           ...  ...        ...        ...
# 3338                   -135.954609    -91.271564   20  52.644530  37.593030
# 10451                  -137.623095    -92.940050   20  50.976044  35.924544
# 9530                   -135.953924    -91.270880   20  52.645214  37.593715
# 7882                   -135.268636    -90.585591   20  53.330503  38.279003
# 7426                   -135.457998    -90.774954   20  53.141140  38.089641
#
#            Eb/No  Propagation Delay  Propagation Distance  \
# 174     0.000000           0.000000              0.000000
# 5787   40.603367           0.001089            326.566361
# 7086   40.920674           0.001050            314.851725
# 2236   40.282913           0.001130            338.839574
# 5883   40.603545           0.001089            326.559660
# ...          ...                ...                   ...
# 3338   40.603330           0.001089            326.567731
# 10451  38.934844           0.001320            395.728729
# 9530   40.604015           0.001089            326.542008
# 7882   41.289303           0.001007            301.769000
# 7426   41.099941           0.001029            308.420158
#
#        Spectral Flux Density    distance
# 174                 0.000000   82.896601
# 5787             -166.323027  340.921736
# 7086             -166.005720  191.153090
# 2236             -166.643481  188.375758
# 5883             -166.322849  313.722195
# ...                      ...         ...
# 3338             -166.323064  115.058497
# 10451            -167.991550   86.669674
# 9530             -166.322380   96.139592
# 7882             -165.637091   96.695765
# 7426             -165.826454   94.768589
#
# [10384 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
UE_date_scaler = StandardScaler()
UE_date_scaler.fit(unscalled_inputs)
# Out:
# StandardScaler()

# %%
scaled_inputs = UE_date_scaler.transform(unscalled_inputs)

# %%
scaled_inputs
# Out:
# array([[-1.67414693e+00, -1.22542336e+00, -1.36127132e+00, ...,
#         -1.77968435e+00,  1.81497037e+00, -1.01208096e+00],
#        [ 1.79237093e-01, -3.53929919e-04,  1.47873831e-01, ...,
#          4.60156462e-01, -5.47140950e-01,  1.11733306e+00],
#        [ 6.09380765e-01, -1.22542336e+00,  6.01067606e-01, ...,
#          3.79808566e-01, -5.42634566e-01, -1.18668443e-01],
#        ...,
#        [ 1.41614793e+00, -3.53929919e-04,  1.30792690e+00, ...,
#          4.59989426e-01, -5.47131750e-01, -9.02790017e-01],
#        [ 8.71034980e-01,  1.22471550e+00, -4.45330135e-01, ...,
#          2.90077275e-01, -5.37399314e-01, -8.98200069e-01],
#        [ 7.20385583e-01,  1.22471550e+00, -8.34503563e-01, ...,
#          3.35695978e-01, -5.40088633e-01, -9.14104548e-01]])

# %%
scaled_inputs.shape
# Out:
# (10384, 21)

# %% [markdown]
# # Splitting The Data for Training and Testing

# %%
from sklearn.model_selection import train_test_split

# %%
# Split 
train_test_split(scaled_inputs, target)
# Out:
# [array([[ 2.54561791e-01, -1.22542336e+00, -1.69894296e+00, ...,
#          -1.77968435e+00,  1.81497037e+00, -7.54983807e-01],
#         [-1.77564110e-01,  1.22471550e+00, -1.91554799e-01, ...,
#           8.77887020e-01, -5.68235897e-01, -9.40155302e-02],
#         [-2.19190917e-01,  1.22471550e+00,  6.63550585e-01, ...,
#           9.03554401e-01, -5.69421584e-01,  6.34744078e-02],
#         ...,
#         [ 1.19017383e+00, -3.53929919e-04, -4.11124749e-02, ...,
#           4.57320547e-01, -5.46984666e-01, -8.78513341e-01],
#         [ 1.34478769e+00, -3.53929919e-04,  7.07914599e-01, ...,
#           4.08849257e-01, -5.44282400e-01,  3.27835379e-01],
#         [ 2.32757273e-01, -1.22542336e+00, -1.52730694e+00, ...,
#          -1.77968435e+00,  1.81497037e+00, -9.71890279e-01]]),
#  array([[ 1.16242263,  1.2247155 , -1.60703039, ...,  0.89130922,
#          -0.56885735,  0.20321331],
#         [ 1.52913498, -1.22542336, -0.775864  , ...,  0.50070076,
#          -0.54935391,  0.32468338],
#         [-0.77817947,  1.2247155 ,  0.47950582, ...,  0.36007002,
#          -0.54150186, -1.03621382],
#         ...,
#         [ 1.0851157 ,  1.2247155 ,  1.465507  , ...,  0.92114704,
#          -0.57022773,  0.2236752 ],
#         [-0.06655929, -1.22542336, -0.17288677, ..., -1.77968435,
#           1.81497037, -0.9407619 ],
#         [-1.09137163, -1.22542336, -0.40118575, ..., -1.77968435,
#           1.81497037, -0.85933185]]),
#  6013    1
#  4709    1
#  4583    1
#  1145    1
#  2576    0
#         ..
#  3945    0
#  7151    1
#  8847    0
#  9314    1
#  5947    1
#  Name: Handover_Ready, Length: 7788, dtype: int32,
#  8765    1
#  9870    0
#  2890    0
#  2965    0
#  8317    0
#         ..
#  6357    0
#  1814    1
#  8531    1
#  5040    1
#  1939    1
#  Name: Handover_Ready, Length: 2596, dtype: int32]

# %%
x_train, X_test, y_train, y_test = train_test_split(scaled_inputs, target, train_size=0.8)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (8307, 21) (8307,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (2077, 21) (2077,)

# %% [markdown]
# # Machine Learnong Model

# %% [markdown]
# # 1. Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()
reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
reg.score(x_train, y_train)
# Out:
# 0.886481280847478

# %%
start_time = time.time()

print("Shape of X train", x_train.shape)
print("Shape of y train", y_train.shape)

"""
Logistic Regression is one of the oldest and most basic algorithms to solve a classification problem:
"""
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)

print("score on test: " + str(lr.score(X_test, y_test)))
print("score on train: "+ str(lr.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = lr.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("---------------------------")
print("Evaluation : LOGISTIC REGRESSION")
print("---------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# Shape of X train (8307, 21)
# Shape of y train (8307,)
# score on test: 0.8849301877708233
# score on train: 0.886481280847478
# Use the trained model to make predictions
# [1 1 0 ... 1 0 1]
#
# ---------------------------
# Evaluation : LOGISTIC REGRESSION
# ---------------------------
# Accuracy:  0.8849301877708233
# MSE:  0.1150698122291767
# Precision: 0.89 / Recall: 0.87
# ROC AUC:  0.8849459424375046
# F1 score: 0.8849179165855303
#
# Run time :  0.0769963264465332 seconds ---

# %% [markdown]
# # 2. Naive Bayes

# %%
start_time = time.time()

print("Shape of X train", x_train.shape)
print("Shape of y train", y_train.shape)

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB


gnb = GaussianNB()
y_pred = gnb.fit(x_train, y_train).predict(X_test)


print("   ")
# Evaluate the predictions of the model on the holdout test set
print("---------------------------")
print("Evaluation : NAIVES BAYES")
print("---------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# Shape of X train (8307, 21)
# Shape of y train (8307,)
#
# ---------------------------
# Evaluation : NAIVES BAYES
# ---------------------------
# Accuracy:  0.7164179104477612
# MSE:  0.2835820895522388
# Precision: 0.97 / Recall: 0.45
# ROC AUC:  0.7168074512276537
# F1 score: 0.6942391400469673
#
# Run time :  0.01199483871459961 seconds ---

# %% [markdown]
# # 3. k-nearest neighbors

# %%
start_time = time.time()
"""
The k-nearest neighbors (KNN) algorithm is a supervised machine learning algorithm that can be used to solve both classification and regression problems.
"""
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(algorithm = 'brute', n_jobs=-1)
knn.fit(x_train, y_train)

print("train shape: " + str(x_train.shape))
print("score on test: " + str(knn.score(X_test, y_test)))
print("score on train: "+ str(knn.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = knn.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("---------------------------")
print("Evaluation : K-NEAREST NEIGHBOURS")
print("---------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# train shape: (8307, 21)
# score on test: 0.980259990370727
# score on train: 0.9910918502467798
# Use the trained model to make predictions
# [1 1 0 ... 0 0 1]
#
# ---------------------------
# Evaluation : K-NEAREST NEIGHBOURS
# ---------------------------
# Accuracy:  0.980259990370727
# MSE:  0.01974000962927299
# Precision: 0.98 / Recall: 0.98
# ROC AUC:  0.9802606446109338
# F1 score: 0.9802599995224901
#
# Run time :  0.5659768581390381 seconds ---

# %% [markdown]
# # 4. Support Vector Machine

# %%
start_time = time.time()

"""
The Support Vector Machine is a simple algorithm for classification and regression tasks. It can provide high accuracy with less computation power very fast. Due to the large number of features, we are using the LinearSVC. It turned out that setting the regularisation parameter C=0.0001 improves the quality of the prediction and reduces overfitting.
"""
from sklearn.svm import LinearSVC

svm=LinearSVC(C=0.0001)
svm.fit(x_train, y_train)

print("score on test: " + str(svm.score(X_test, y_test)))
print("score on train: "+ str(svm.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = svm.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("-----------------------------------")
print("Evaluation : SUPPORT VECTOR MACHINE")
print("-----------------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# score on test: 0.8208955223880597
# score on train: 0.8197905381003973
# Use the trained model to make predictions
# [1 1 0 ... 0 0 1]
#
# -----------------------------------
# Evaluation : SUPPORT VECTOR MACHINE
# -----------------------------------
# Accuracy:  0.8208955223880597
# MSE:  0.1791044776119403
# Precision: 0.92 / Recall: 0.71
# ROC AUC:  0.821062050293005
# F1 score: 0.818502841098704
#
# Run time :  0.04300045967102051 seconds ---

# %% [markdown]
# # 5. Decision Tree

# %%
start_time = time.time()

"""
A Decision Tree is a non-parametric supervised learning method used for classification and regression. The goal is to create a model that predicts the value of a target variable by learning simple decision rules (if-else) inferred from the data features.
"""
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
print("   ")
print("score on test: "  + str(clf.score(X_test, y_test)))
print("score on train: " + str(clf.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = clf.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("---------------------------")
print("Evaluation : DECISION TREE")
print("---------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
#
# score on test: 0.9942224362060664
# score on train: 1.0
# Use the trained model to make predictions
# [1 1 0 ... 1 0 1]
#
# ---------------------------
# Evaluation : DECISION TREE
# ---------------------------
# Accuracy:  0.9942224362060664
# MSE:  0.005777563793933558
# Precision: 0.99 / Recall: 1.0
# ROC AUC:  0.9942210333061346
# F1 score: 0.9942224228131774
#
# Run time :  0.06699919700622559 seconds ---

# %% [markdown]
# # 6. Bagging Decision Tree

# %%
start_time = time.time()

"""
When a decision tree overfits, applying an ensemble learning algorithm like bagging might improve the quality of the prediction model. In bagging, the training data is increased by taking bootstraps from the training data. This means multiple samples are taken (with replacement) from the training data and the model is trained on these sub-datasets. The final prediction is the average over all predictions from each bootstrap sample.
"""
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# max_samples: maximum size 0.5=50% of each sample taken from the full dataset
# max_features: maximum of features 1=100% taken here all 10K 
# n_estimators: number of decision trees 
bg=BaggingClassifier(DecisionTreeClassifier(),max_samples=0.5,max_features=1.0,n_estimators=10)
bg.fit(x_train, y_train)

print("score on test: " + str(bg.score(X_test, y_test)))
print("score on train: "+ str(bg.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = bg.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("----------------------------------")
print("Evaluation : BAGGING DECISION TREE")
print("----------------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# score on test: 0.9918151179585941
# score on train: 0.9984350547730829
# Use the trained model to make predictions
# [1 1 0 ... 1 0 1]
#
# ----------------------------------
# Evaluation : BAGGING DECISION TREE
# ----------------------------------
# Accuracy:  0.9918151179585941
# MSE:  0.008184882041405874
# Precision: 0.99 / Recall: 1.0
# ROC AUC:  0.9918102329204065
# F1 score: 0.9918149851434679
#
# Run time :  0.2789907455444336 seconds ---

# %% [markdown]
# # 7. Boosting Decision Tree

# %%
start_time = time.time()

"""
In general, we can’t use Boosting to improve a completely overfitted model with score = 1. To apply Boosting, we first have to tweak the decision tree classifier a bit. It took me some trial and error until I got the best parameters for the Decision Tree and the AdaBoost Classifier. I am sure you can further improve by playing around a bit more.
"""
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

adb = AdaBoostClassifier(DecisionTreeClassifier(min_samples_split=10,max_depth=4),n_estimators=10,learning_rate=0.6)
adb.fit(x_train, y_train)

print("score on test: " + str(adb.score(X_test, y_test)))
print("score on train: "+ str(adb.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = adb.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("-----------------------------------")
print("Evaluation : BOOSTING DECISION TREE")
print("-----------------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# score on test: 1.0
# score on train: 1.0
# Use the trained model to make predictions
# [1 1 0 ... 0 0 1]
#
# -----------------------------------
# Evaluation : BOOSTING DECISION TREE
# -----------------------------------
# Accuracy:  1.0
# MSE:  0.0
# Precision: 1.0 / Recall: 1.0
# ROC AUC:  1.0
# F1 score: 1.0
#
# Run time :  0.5109977722167969 seconds ---

# %% [markdown]
# # 8. Random Forest

# %%
start_time = time.time()

"""
The Random Forest Algorithm is another frequently used ensemble learning classifier which uses multiple decision trees. The Random Forest classifier is basically a modified bagging algorithm of a Decision Tree that selects the subsets differently. I found out that max_depth=9 is a good value for this feature-rich dataset
"""
from sklearn.ensemble import RandomForestClassifier
# n_estimators = number of decision trees
rf = RandomForestClassifier(n_estimators=30, max_depth=9)
rf.fit(x_train, y_train)

print("score on test: " + str(rf.score(X_test, y_test)))
print("score on train: "+ str(rf.score(x_train, y_train)))

# Use the trained model to make predictions
print("Use the trained model to make predictions")
y_pred = rf.predict(X_test)
print(y_pred)

print("   ")
# Evaluate the predictions of the model on the holdout test set
print("--------------------------")
print("Evaluation : RANDOM FOREST")
print("--------------------------")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("Precision: {} / Recall: {} ".format(round(precision, 2), round(recall, 2)))
print("ROC AUC: ", roc_auc_score(y_test, y_pred))
print("F1 score:", metrics.f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred)))
print("   ")

print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# score on test: 0.9961482908040443
# score on train: 0.9996388587937883
# Use the trained model to make predictions
# [1 1 0 ... 0 0 1]
#
# --------------------------
# Evaluation : RANDOM FOREST
# --------------------------
# Accuracy:  0.9961482908040443
# MSE:  0.0038517091959557053
# Precision: 1.0 / Recall: 1.0
# ROC AUC:  0.9961468919219643
# F1 score: 0.9961482818754516
#
# Run time :  0.3620188236236572 seconds ---

# %% [markdown]
# # Feature importance

# %%
sort = rf.feature_importances_.argsort()
plt.barh(classifier_UE_data.columns[sort], rf.feature_importances_[sort])
plt.xlabel("Feature Importance")
plt.savefig('Feature_Importance.png')
plt.savefig('Feature_Importance.jpeg')

# %% [markdown]
# # Correlation Matrix

# %%
# Visualizing a Pandas Correlation Matrix Using Seaborn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


matrix = classifier_UE_data.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()
plt.savefig('CorrelationMatrix.png')

# %% [markdown]
# # 2. Neural Network

# %%
# Learning model parameters
epochs = 75
batch_size = 15
dr = 0.1

# %%
classifier = Sequential()
#First Hidden Layer
classifier.add(Dense(4, activation='relu', kernel_initializer='random_normal', input_dim=21))
#Second  Hidden Layer
classifier.add(Dense(4, activation='relu', kernel_initializer='random_normal'))
#Output Layer
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))
#Compiling the neural network
classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =['accuracy'])
classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 4)                 88
#
#  dense_10 (Dense)            (None, 4)                 20
#
#  dense_11 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.time()
#Fitting the data to the training dataset
history =classifier.fit(x_train,y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test))
print("Run time :  %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/75
# 554/554 [==============================] - 2s 2ms/step - loss: 0.6113 - accuracy: 0.7249 - val_loss: 0.4994 - val_accuracy: 0.8305
# Epoch 2/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.4212 - accuracy: 0.8764 - val_loss: 0.3584 - val_accuracy: 0.9003
# Epoch 3/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.3180 - accuracy: 0.9155 - val_loss: 0.2849 - val_accuracy: 0.9143
# Epoch 4/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.2592 - accuracy: 0.9295 - val_loss: 0.2397 - val_accuracy: 0.9239
# Epoch 5/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.2221 - accuracy: 0.9346 - val_loss: 0.2113 - val_accuracy: 0.9292
# Epoch 6/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1988 - accuracy: 0.9382 - val_loss: 0.1905 - val_accuracy: 0.9345
# Epoch 7/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1830 - accuracy: 0.9410 - val_loss: 0.1771 - val_accuracy: 0.9360
# Epoch 8/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1717 - accuracy: 0.9439 - val_loss: 0.1687 - val_accuracy: 0.9514
# Epoch 9/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1643 - accuracy: 0.9470 - val_loss: 0.1616 - val_accuracy: 0.9523
# Epoch 10/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1588 - accuracy: 0.9480 - val_loss: 0.1560 - val_accuracy: 0.9456
# Epoch 11/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1547 - accuracy: 0.9478 - val_loss: 0.1544 - val_accuracy: 0.9533
# Epoch 12/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1520 - accuracy: 0.9521 - val_loss: 0.1490 - val_accuracy: 0.9456
# Epoch 13/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1499 - accuracy: 0.9509 - val_loss: 0.1475 - val_accuracy: 0.9528
# Epoch 14/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1485 - accuracy: 0.9499 - val_loss: 0.1470 - val_accuracy: 0.9543
# Epoch 15/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1472 - accuracy: 0.9506 - val_loss: 0.1454 - val_accuracy: 0.9533
# Epoch 16/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1465 - accuracy: 0.9505 - val_loss: 0.1432 - val_accuracy: 0.9552
# Epoch 17/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1450 - accuracy: 0.9523 - val_loss: 0.1449 - val_accuracy: 0.9543
# Epoch 18/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1450 - accuracy: 0.9514 - val_loss: 0.1428 - val_accuracy: 0.9543
# Epoch 19/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1443 - accuracy: 0.9521 - val_loss: 0.1423 - val_accuracy: 0.9437
# Epoch 20/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1438 - accuracy: 0.9523 - val_loss: 0.1386 - val_accuracy: 0.9514
# Epoch 21/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1430 - accuracy: 0.9517 - val_loss: 0.1418 - val_accuracy: 0.9417
# Epoch 22/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.
75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1378 - accuracy: 0.9527 - val_loss: 0.1285 - val_accuracy: 0.9567
# Epoch 55/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1373 - accuracy: 0.9521 - val_loss: 0.1296 - val_accuracy: 0.9552
# Epoch 56/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1374 - accuracy: 0.9529 - val_loss: 0.1286 - val_accuracy: 0.9562
# Epoch 57/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9526 - val_loss: 0.1301 - val_accuracy: 0.9547
# Epoch 58/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9516 - val_loss: 0.1299 - val_accuracy: 0.9523
# Epoch 59/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9527 - val_loss: 0.1275 - val_accuracy: 0.9552
# Epoch 60/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1374 - accuracy: 0.9537 - val_loss: 0.1270 - val_accuracy: 0.9557
# Epoch 61/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1368 - accuracy: 0.9537 - val_loss: 0.1310 - val_accuracy: 0.9543
# Epoch 62/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1374 - accuracy: 0.9521 - val_loss: 0.1303 - val_accuracy: 0.9533
# Epoch 63/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1368 - accuracy: 0.9528 - val_loss: 0.1283 - val_accuracy: 0.9557
# Epoch 64/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1365 - accuracy: 0.9535 - val_loss: 0.1300 - val_accuracy: 0.9470
# Epoch 65/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1366 - accuracy: 0.9540 - val_loss: 0.1272 - val_accuracy: 0.9557
# Epoch 66/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1368 - accuracy: 0.9512 - val_loss: 0.1283 - val_accuracy: 0.9543
# Epoch 67/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1366 - accuracy: 0.9511 - val_loss: 0.1288 - val_accuracy: 0.9499
# Epoch 68/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1364 - accuracy: 0.9523 - val_loss: 0.1284 - val_accuracy: 0.9547
# Epoch 69/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1363 - accuracy: 0.9524 - val_loss: 0.1275 - val_accuracy: 0.9543
# Epoch 70/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1363 - accuracy: 0.9526 - val_loss: 0.1283 - val_accuracy: 0.9490
# Epoch 71/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1359 - accuracy: 0.9521 - val_loss: 0.1270 - val_accuracy: 0.9538
# Epoch 72/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1362 - accuracy: 0.9529 - val_loss: 0.1272 - val_accuracy: 0.9552
# Epoch 73/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1356 - accuracy: 0.9516 - val_loss: 0.1270 - val_accuracy: 0.9567
# Epoch 74/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1349 - accuracy: 0.9524 - val_loss: 0.1332 - val_accuracy: 0.9519
# Epoch 75/75
# 554/554 [==============================] - 1s 2ms/step - loss: 0.1353 - accuracy: 0.9527 - val_loss: 0.1274 - val_accuracy: 0.9538
# Run time :  77.38027358055115 seconds ---

# %%
eval_model=classifier.evaluate(x_train, y_train)
eval_model
# Out:
# 260/260 [==============================] - 0s 1ms/step - loss: 0.1352 - accuracy: 0.9508
# [0.13519372045993805, 0.9507644176483154]

# %%
# Check how loss & mse went down
epoch_loss = history.history['loss']
epoch_val_loss = history.history['val_loss']
epoch_mae = history.history['accuracy']
epoch_val_mae = history.history['val_accuracy']

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Test Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.savefig('Figure_14_Loss.png')
plt.savefig('Figure_14_Loss.jpeg')
plt.title('Loss')
plt.legend(loc='best')

plt.show()

# %%
# Check how loss & mse went down
epoch_loss = history.history['loss']
epoch_val_loss = history.history['val_loss']
epoch_mae = history.history['accuracy']
epoch_val_mae = history.history['val_accuracy']

plt.figure(figsize=(12,4))
plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mae)), epoch_mae, 'b-', linewidth=2, label='Train Acc')
plt.plot(range(0,len(epoch_val_mae)), epoch_val_mae, 'r-', linewidth=2,label='Test Acc')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title('Accuracy')
plt.legend(loc='best')
plt.show()
plt.savefig('Figure_Acc.jpeg')

# %%
y_pred=classifier.predict(X_test)
y_pred =(y_pred>0.5)
# Out:
# 65/65 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[996  41]
#  [ 75 965]]

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
